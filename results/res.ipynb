# %%
import pandas as pd
import pyarrow.parquet as pq

# %%
# Lire le fichier Parquet
top10_full_df_2w = pq.read_table("top10_full_df_2w/results_top10_full_df_2w_part-00000-503ff511-8804-4146-ad6b-84ef21ba193c-c000.snappy.parquet").to_pandas()

top10_full_df_2w.head()
# Out:
#                                                  src          rank
# 0  http://dbpedia.org/resource/Category:Living_pe...  18143.166795
# 1          http://dbpedia.org/resource/United_States   9903.067869
# 2  http://dbpedia.org/resource/Race_and_ethnicity...   7620.315806
# 3  http://dbpedia.org/resource/List_of_sovereign_...   7286.186336
# 4           http://dbpedia.org/resource/World_War_II   6491.255466

# %%
# Lire le fichier Parquet
top10_full_df_4w = pq.read_table("top10_full_df_4w/results_top10_full_df_4w_part-00000-c14f7555-1b2a-45c7-ae50-2fe14373a406-c000.snappy.parquet").to_pandas()

top10_full_df_4w.head()
# Out:
#                                                  src          rank
# 0  http://dbpedia.org/resource/Category:Living_pe...  18143.166795
# 1          http://dbpedia.org/resource/United_States   9903.067869
# 2  http://dbpedia.org/resource/Race_and_ethnicity...   7620.315806
# 3  http://dbpedia.org/resource/List_of_sovereign_...   7286.186336
# 4           http://dbpedia.org/resource/World_War_II   6491.255466

# %%
# Lire le fichier Parquet
top10_full_df_6w = pq.read_table("top10_full_df_6w/results_top10_full_df_6w_part-00000-f9af8833-e5c2-443c-b4d3-6c80bdd24914-c000.snappy.parquet").to_pandas()

top10_full_df_6w.head()
# Out:
#                                                  src          rank
# 0  http://dbpedia.org/resource/Category:Living_pe...  18143.166795
# 1          http://dbpedia.org/resource/United_States   9903.067869
# 2  http://dbpedia.org/resource/Race_and_ethnicity...   7620.315806
# 3  http://dbpedia.org/resource/List_of_sovereign_...   7286.186336
# 4           http://dbpedia.org/resource/World_War_II   6491.255466

# %%
# Lire le fichier Parquet
top10_full_rdd_2w = pq.read_table("top10_full_rdd_2w/results_top10_full_rdd_2w_part-00000-995559b3-ffde-4b90-b9b5-210a47784ad8-c000.snappy.parquet").to_pandas()

top10_full_rdd_2w.head()
# Out:
#                                                 node          rank
# 0  http://dbpedia.org/resource/Category:Living_pe...  14653.835652
# 1          http://dbpedia.org/resource/United_States   8336.131327
# 2  http://dbpedia.org/resource/Race_and_ethnicity...   6808.266898
# 3  http://dbpedia.org/resource/List_of_sovereign_...   5645.908898
# 4           http://dbpedia.org/resource/World_War_II   5632.918628

# %%
# Lire le fichier Parquet
top10_full_rdd_4w = pq.read_table("top10_full_rdd_4w/results_top10_full_rdd_4w_part-00000-ce7aea58-4ad7-4eca-9293-cc9fb37f0b7c-c000.snappy.parquet").to_pandas()

top10_full_rdd_4w.head()
# Out:
#                                                 node          rank
# 0  http://dbpedia.org/resource/Category:Living_pe...  14653.835652
# 1          http://dbpedia.org/resource/United_States   8336.131327
# 2  http://dbpedia.org/resource/Race_and_ethnicity...   6808.266898
# 3  http://dbpedia.org/resource/List_of_sovereign_...   5645.908898
# 4           http://dbpedia.org/resource/World_War_II   5632.918628

# %%
# Lire le fichier Parquet
top10_full_rdd_6w = pq.read_table("top10_full_rdd_6w/results_top10_full_rdd_6w_part-00000-6335a1f2-8de7-487b-a2fd-dff8f67c9613-c000.snappy.parquet").to_pandas()

top10_full_rdd_6w.head()
# Out:
#                                                 node          rank
# 0  http://dbpedia.org/resource/Category:Living_pe...  14653.835652
# 1          http://dbpedia.org/resource/United_States   8336.131327
# 2  http://dbpedia.org/resource/Race_and_ethnicity...   6808.266898
# 3  http://dbpedia.org/resource/List_of_sovereign_...   5645.908898
# 4           http://dbpedia.org/resource/World_War_II   5632.918628
